# %% [markdown]
# # Homework 1

# %%
# !pip install parameterized

import unittest
from parameterized import parameterized

# %% [markdown]
# ## HW 1-1. Multiplication Table (구구단)
#
# 주어진 정수 `x` 에 대하여 x단 구구단 결과를 list로 반환하세요.
#
# (Numpy 등 다른 library 없이 기본 문법 (for / if 등) 만을 사용하여 구현할 것)
#
# **Example:**
# ```
# Input: x = 2
# Output: [2, 4, 6, 8, 10, 12, 14, 16, 18]
# ```

# %%
def multiplication_table(x):
  '''
  Make multiplication table.

  Args:
    x: Input integer

  Returns:
    List of integers
  '''
  pass  # remove this line and add your implementation

# %%
# Test code for multiplication_table function

class TestHomework1_1(unittest.TestCase):
    
  @parameterized.expand([
                        (2, [2, 4, 6, 8, 10, 12, 14, 16, 18]),
                        (3, [3, 6, 9, 12, 15, 18, 21, 24, 27]),
                        (5, [5, 10, 15, 20, 25, 30, 35, 40, 45])
    ])
  
  def test_multiplication_table(self, x, a):
    self.assertEqual(multiplication_table(x), a)

_ = unittest.main(TestHomework1_1(), argv=[''], verbosity=2, exit=False)

# %% [markdown]
# ## HW 1-2. Two Sum
#
# Given an array of integers `nums` and an integer `target`, return *indices of the two numbers such that they add up to `target`.*
#
# You may assume that each input would have **exactly one solution**, and you may not use the same element twice. Only one valid answer exists.
#
#
# You can return the answer in any order.
#
# **Example:**
#
# ```
# Input: nums = [2,7,11,15], target = 9
# Output: [0,1]
# Because nums[0] + nums[1] == 9, we return [0, 1].
# ```
#
# 문제출처: leetcode

# %%
def two_sum(nums, target):
  '''
  Solve 'two sum' problem.

  Args:
    nums: list of integers
    target: target number (integer)

  Returns:
    List of indices (integers)
  '''
  pass  # remove this line and add your implementation

# %%
# Test code for two_sum function

class TestHomework1_2(unittest.TestCase):
    
  @parameterized.expand([
                        ([2, 7, 11, 15], 9, [0, 1]),
                        ([3, 2, 4], 6, [1, 2]),
                        ([3, 3], 6, [0, 1])
    ])
  
  def test_two_sum(self, nums, target, expected_result):
    result = two_sum(nums, target)
    result.sort()
    self.assertEqual(result, expected_result)
        
_ = unittest.main(TestHomework1_2(), argv=[''], verbosity=2, exit=False)

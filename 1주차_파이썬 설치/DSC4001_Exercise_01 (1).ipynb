# %% [markdown]
# # DSC4001-01 Exercise 01

# %% [markdown]
# 다음을 입력하세요.
# ```
# print('Welcome to DSC4001 Python Programming for Data Science!')
# ```

# %%
# 여기에 입력하세요.

# %% [markdown]
# 다음을 입력하세요.
#
# ```
# a = 1 + 2
# b = a * 3
# print('a:', a)
# print('b:', b)
# ```

# %%
# 여기에 입력하세요.

# %% [markdown]
# b의 값을 바꿔보세요.
#
#  ```
# b = a * 5
# print('a:', a)
# print('b:', b)
#  ```

# %%
# 여기에 입력하세요.

# %% [markdown]
# Matplotlib으로 그래프를 그려봅니다.
# 다음을 입력하세요.
#
# ```
# import numpy as np
# from matplotlib import pyplot as plt
#
# ys = 200 + np.random.randn(100)
# x = [x for x in range(len(ys))]
#
# plt.plot(x, ys, '-')
# plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='g', alpha=0.6)
#
# plt.title("Sample Visualization")
# plt.show()
# ```

# %%
# 여기에 입력하세요.

# %% [markdown]
# Python basics를 다루어봅니다.
# 다음을 입력하세요.
#
# **Functions, Conditions, and Iteration**
#
# ```
# def HelloWorldXY(x,y):
#   if (x < 10):
#     print('Hello World, x < 10')
#   elif (x < 20):
#     print('Hello World, x >= 10 but x < 20')
#   else:
#     print('Hello World, x >= 20')
#
#   return x+y
# ```

# %%
# 여기에 입력하세요.

# %% [markdown]
# 함수를 실행해봅니다.
# 다음을 입력하세요.
#
# ```
# for i in range(8, 25, 5): # (start, stop, step) i=8,13,18,23
#   print('--- Now running with i: {}'.format(i))
#   r = HelloWorldXY(i,i)
#   print('Result from HelloWorldXY: {}'.format(r))
#
#
# print('\n\n')
# print('--- Running HelloWorldXY(1,2)')
# print(HelloWorldXY(1,2))
# ```

# %%
# 여기에 입력하세요.
